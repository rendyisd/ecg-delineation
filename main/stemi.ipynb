# %%
import confmain
import matplotlib.pyplot as plt

from util_module import util_func
from util_module.ecg_signal import ECGSignal

# %% [markdown]
# STEMI Records [7, 21, 24, 33, 55, 64, 69, 86]

# %%
ecg = ECGSignal.load_ecg_signal(7, 'ii')

fig1 = plt.figure(figsize=(28, 4))
ax = fig1.add_subplot(111)
ecg.plot_segments(ax=ax)
ax.set(title='Record 7', xlabel='Nodes', ylabel='Amplitude (mV)')
# Out:
# [Text(0.5, 1.0, 'Record 7'),
#  Text(0.5, 0, 'Nodes'),
#  Text(0, 0.5, 'Amplitude (mV)')]

# %%
ecg = ECGSignal.load_ecg_signal(21, 'ii')

fig2 = plt.figure(figsize=(28, 4))
ax = fig2.add_subplot(111)
ecg.plot_segments(ax=ax)
ax.set(title='Record 21', xlabel='Nodes', ylabel='Amplitude (mV)')
# Out:
# [Text(0.5, 1.0, 'Record 21'),
#  Text(0.5, 0, 'Nodes'),
#  Text(0, 0.5, 'Amplitude (mV)')]

# %%
ecg = ECGSignal.load_ecg_signal(24, 'ii')

fig3 = plt.figure(figsize=(28, 4))
ax = fig3.add_subplot(111)
ecg.plot_segments(ax=ax)
ax.set(title='Record 24', xlabel='Nodes', ylabel='Amplitude (mV)')
# Out:
# [Text(0.5, 1.0, 'Record 24'),
#  Text(0.5, 0, 'Nodes'),
#  Text(0, 0.5, 'Amplitude (mV)')]

# %%
ecg = ECGSignal.load_ecg_signal(33, 'ii')

fig4 = plt.figure(figsize=(28, 4))
ax = fig4.add_subplot(111)
ecg.plot_segments(ax=ax)
ax.set(title='Record 33', xlabel='Nodes', ylabel='Amplitude (mV)')
# Out:
# [Text(0.5, 1.0, 'Record 33'),
#  Text(0.5, 0, 'Nodes'),
#  Text(0, 0.5, 'Amplitude (mV)')]

# %%
ecg = ECGSignal.load_ecg_signal(55, 'ii')

fig5 = plt.figure(figsize=(28, 4))
ax = fig5.add_subplot(111)
ecg.plot_segments(ax=ax)
ax.set(title='Record 55', xlabel='Nodes', ylabel='Amplitude (mV)')
# Out:
# [Text(0.5, 1.0, 'Record 55'),
#  Text(0.5, 0, 'Nodes'),
#  Text(0, 0.5, 'Amplitude (mV)')]

# %%
fig1.savefig('../result/LEAD_ii_STEMI_Record_7.jpg', bbox_inches='tight')
fig2.savefig('../result/LEAD_ii_STEMI_Record_21.jpg', bbox_inches='tight')
fig3.savefig('../result/LEAD_ii_STEMI_Record_24.jpg', bbox_inches='tight')
fig4.savefig('../result/LEAD_ii_STEMI_Record_33.jpg', bbox_inches='tight')
fig5.savefig('../result/LEAD_ii_STEMI_Record_55.jpg', bbox_inches='tight')
